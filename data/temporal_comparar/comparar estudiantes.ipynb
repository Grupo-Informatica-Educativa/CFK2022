# %%
import pandas as pd

# %%
est_0 = pd.read_excel('EstudiantesCFK.xlsx')
est_1 = pd.read_excel("../descargables/EstudiantesCFK.xlsx")

# %%
est_0
# Out:
#       N registro Deseo participar en el estudio  Código IE  Grupo  \
# 0              1                             Sí        166      2
# 1              2                             Sí        166      2
# 2              3                             Sí        166      2
# 3              4                             Sí        166      2
# 4              5                             Sí        166      2
# ...          ...                            ...        ...    ...
# 20795      D1407                             Sí        215      8
# 20796      D1408                             Sí        215      8
# 20797      D1409                             Sí        215      8
# 20798      D1410                             Sí        215      8
# 20799      D1411                             Sí        215      8
#
#                               Nombre  Fecha         ID  Número de lista  Edad  \
# 0                                NaN  19/04  166090203                3    14
# ...

# %%
est_1
# Out:
#       N registro Deseo participar en el estudio  Código IE  Grupo  \
# 0              1                             Sí        166      2
# 1              2                             Sí        166      2
# 2              3                             Sí        166      2
# 3              4                             Sí        166      2
# 4              5                             Sí        166      2
# ...          ...                            ...        ...    ...
# 22894      D2012                             Sí        134      6
# 22895      D2013                             Sí        134      6
# 22896      D2014                             Sí        134      6
# 22897      D2015                             Sí        134      6
# 22898      D2016                             Sí        134      6
#
#                                   Nombre  Fecha         ID  Número de lista  \
# 0                                    NaN  19/04  166090203                3
# ...

# %%
registros_ya_no_estan = set(est_0['N registro']).difference(set(est_1['N registro']))

# %%
est_0[est_0['N registro'].isin(registros_ya_no_estan)]
# Out:
#       N registro Deseo participar en el estudio  Código IE  Grupo  \
# 3947        4505                             Sí        248      3
# 3950        4508                             Sí        248      3
# 12157      13324                             Sí        217      3
# 14075      15405                             Sí        217      3
# 14182      15518                             Sí        217      3
# 14213      15549                             Sí        217      3
# 14290      15630                             Sí        217      3
# 14299      15639                             Sí        217      3
# 14320      15660                             Sí        217      3
# 14330      15670                             Sí        217      3
# 14343      15683                             Sí        217      3
# 14350      15690                             Sí        217      3
# 14383      15723                             Sí        217      3
# ...
